# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sec = pd.read_csv("Main.csv")
df_sec
# Out:
#                         Location Percentage  Zip Code Urban/Rural
# 0                      Togus, ME     95.73%    4330.0       Rural
# 1                          Togus     94.83%    4330.0       Rural
# 2     Aroostook County (Caribou)     97.92%    4736.0       Rural
# 3                         Calais     99.74%    4619.0       Rural
# 4                        Rumford       100%    4276.0       Rural
# ...                          ...        ...       ...         ...
# 1007   Western Central Minnesota     97.97%   56320.0       Rural
# 1008                      Wausau     98.40%   54401.0       Urban
# 1009                  Eau Claire     99.20%   54701.0       Urban
# 1010                     Ashland     99.69%   54806.0       Rural
# 1011                    Ironwood     99.56%   49938.0       Rural
#
# [1012 rows x 4 columns]
